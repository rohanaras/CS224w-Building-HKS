# %%
import pandas as pd

# %%
land_use_dict = {
    1: 'One & Two Family Buildings', # Res
    2: 'Multi-Family Walk-Up Buildings', # Res
    3: 'Multi-Family Elevator Buildings', # Res
    4: 'Mixed Residential & Commercial Buildings', # Mixed Res/Com
    5: 'Commercial & Office Buildings', # Com/Off
    6: 'Industrial & Manufacturing', # Ind
    7: 'Transportation & Utility', # Infra
    8: 'Public Facilities & Institutions', # Gov
    9: 'Open Space & Outdoor Recreation', # Parks 
    10: 'Parking Facilities', # Parking
    11: 'Vacant Land' # Vacant
}

# %%
pluto = pd.read_csv('pluto_utm.csv')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (20,21,23,24,25,26,27,65,66,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pluto.shape
# Out:
# (834225, 90)

# %%
for lu in land_use_dict.keys():
    print(land_use_dict[lu], pluto.loc[(pluto.LandUse==lu) & (~pluto.lat.isnull())].shape[0])
# Out:
# One & Two Family Buildings 564407
# Multi-Family Walk-Up Buildings 130609
# Multi-Family Elevator Buildings 12289
# Mixed Residential & Commercial Buildings 51834
# Commercial & Office Buildings 22121
# Industrial & Manufacturing 10985
# Transportation & Utility 2489
# Public Facilities & Institutions 12091
# Open Space & Outdoor Recreation 2140
# Parking Facilities 10501
# Vacant Land 12875

# %%
man_lu5 = pluto.loc[(pluto.LandUse==5) & (~pluto.lat.isnull()) & (pluto.BoroCode==1)]
man_lu5 = man_lu5.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
man_lu5[['lon', 'lat', 'utm18_x', 'utm18_y', 'BoroCode']].to_csv('man_lu5_utm.csv', index=False)

# %%
lu5 = pluto.loc[(pluto.LandUse==5) & (~pluto.lat.isnull())]
lu5 = lu5.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
lu5[['lon', 'lat', 'utm18_x', 'utm18_y', 'BoroCode']].to_csv('lu5_utm.csv', index=False)

# %%
lu9 = pluto.loc[(pluto.LandUse==9) & (~pluto.lat.isnull())]
lu9 = lu9.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
lu9[['lon', 'lat', 'utm18_x', 'utm18_y', 'BoroCode']].to_csv('lu9_utm.csv', index=False)

# %%
lu5.loc[lu5.BoroCode==2].shape
# Out:
# (2978, 88)

# %%
lu2 = pluto.loc[(pluto.LandUse==2) & (~pluto.lat.isnull())]
lu2 = lu2.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
lu2[['lon', 'lat', 'utm18_x', 'utm18_y', 'BoroCode']].to_csv('lu2_utm.csv', index=False)

# %%
lu3 = pluto.loc[(pluto.LandUse==3) & (~pluto.lat.isnull())]
lu3 = lu3.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
lu3[['lon', 'lat', 'utm18_x', 'utm18_y', 'BoroCode']].to_csv('lu3_utm.csv', index=False)

# %%
import matplotlib.pyplot as plt
# mask = pluto.utm18_x.between(585000, 589000) & pluto.utm18_y.between(4500000, 4504000)
mask = pluto.utm18_x.between(584500, 586000) & pluto.utm18_y.between(4510300, 4511800)
midtown = pluto.loc[mask, ['utm18_x', 'utm18_y']]
f, ax = plt.subplots(figsize=(15,15))
ax.scatter(small_square.loc[:, 'utm18_x'], small_square.loc[:, 'utm18_y'], s=1)
ax.set_aspect('equal')
plt.show()
midtown.to_csv('midtown_utm.csv', index=False)
